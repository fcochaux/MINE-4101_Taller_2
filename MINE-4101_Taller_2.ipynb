# %% [markdown]
# <a href="https://colab.research.google.com/github/fcochaux/MINE-4101_Taller_2/blob/main/MINE-4101_Taller_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller 2 de Ciencia de Datos Aplicada
#
# **Estudiante:** Francisco José Chaux Guzmán <br/>
# **Código:** 202210155 <br/>
# **Programa:** Maestría en Ingeniería de la Información

# %% [markdown]
# Enlace al repositorio de este taller:

# %%
# !git clone "https://github.com/fcochaux/MINE-4101_Taller_2.git"
# Out:
# fatal: destination path 'MINE-4101_Taller_2' already exists and is not an empty directory.

# %%
pd.read_csv('/content/MINE-4101_Taller_2/datos/Data_Taller_2.csv', sep = ';')
# Out:
#      instant        Date    Season Holiday            Weather      Temp  \
# 0          1   1/01/2020  Springer      No      Mist + Cloudy  8,175849
# 1          2   2/01/2020  Springer      No      Mist + Cloudy  9,083466
# 2          3   3/01/2020  Springer      No         Few clouds  1,229108
# 3          4   4/01/2020  Springer      No         Few clouds       1,4
# 4          5   5/01/2020  Springer      No   Partly    cloudy  2,666979
# ..       ...         ...       ...     ...                ...       ...
# 726      727  27/12/2021  Springer      No      Mist + Cloudy  3,945849
# 727      728  28/12/2021  Springer      No  Mist + Few clouds  3,906651
# 728      729  29/12/2021  Springer      No               Mist  3,906651
# 729      730  30/12/2021  Springer      No         Few clouds  4,024151
# 730      731  31/12/2021  Springer      No  Mist + Few clouds  2,144151
#
#     Feel_Temp       Hum        Wind  Casual  Registered   cnt
# ...
